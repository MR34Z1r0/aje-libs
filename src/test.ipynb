# %%
import aje_libs.bd.helpers.pinecone_helper
import importlib
importlib.reload(aje_libs.bd.helpers.pinecone_helper)
# Out:
# <module 'aje_libs.bd.helpers.pinecone_helper' from 'd:\\WORKSPACE-GIT\\CDK\\aje-libs\\src\\aje_libs\\bd\\helpers\\pinecone_helper.py'>

# %%
from aje_libs.bd.helpers.pinecone_helper import PineconeHelper
from aje_libs.common.helpers.secrets_helper import SecretsHelper
from aje_libs.common.helpers.ssm_helper import SSMParameterHelper
import json 
import boto3 

boto3.setup_default_session(profile_name='prd-upeu-admin')

ENVIRONMENT = 'dev'
PROJECT_NAME = 'agent-resources'
ssm_chatbot = SSMParameterHelper(f"/{ENVIRONMENT}/{PROJECT_NAME}/chatbot")
PARAMETER_VALUE = json.loads(ssm_chatbot.get_parameter_value())
CHATBOT_MODEL_ID = PARAMETER_VALUE["CHATBOT_MODEL_ID"]
CHATBOT_REGION = PARAMETER_VALUE["CHATBOT_REGION"]
CHATBOT_LLM_MAX_TOKENS = int(PARAMETER_VALUE["CHATBOT_LLM_MAX_TOKENS"])
CHATBOT_HISTORY_ELEMENTS = int(PARAMETER_VALUE["CHATBOT_HISTORY_ELEMENTS"])
PINECONE_MAX_RETRIEVE_DOCUMENTS = int(PARAMETER_VALUE["PINECONE_MAX_RETRIEVE_DOCUMENTS"])
PINECONE_MIN_THRESHOLD = float(PARAMETER_VALUE["PINECONE_MIN_THRESHOLD"])
EMBEDDINGS_MODEL_ID = PARAMETER_VALUE["EMBEDDINGS_MODEL_ID"]
EMBEDDINGS_REGION = PARAMETER_VALUE["EMBEDDINGS_REGION"]

secret_pinecone = SecretsHelper(f"{ENVIRONMENT}/{PROJECT_NAME}/pinecone-api-key")

PINECONE_INDEX_NAME = secret_pinecone.get_secret_value("PINECONE_INDEX_NAME")
PINECONE_API_KEY = secret_pinecone.get_secret_value("PINECONE_API_KEY")


pinecone_helper = PineconeHelper(
    index_name=PINECONE_INDEX_NAME,
    api_key=PINECONE_API_KEY,
    embeddings_model_id=EMBEDDINGS_MODEL_ID,
    embeddings_region=CHATBOT_REGION,
    max_retrieve_documents=PINECONE_MAX_RETRIEVE_DOCUMENTS,
    min_threshold=PINECONE_MIN_THRESHOLD
)
# Out:
# {"level":"INFO","location":"__init__:22","message":"Inicializando SSMParameterHelper para el parámetro: /dev/agent-resources/chatbot","timestamp":"2025-05-13 17:48:06,378-0500","service":"service_undefined","name":"aje_libs.bd.helpers.pinecone_helper"}
# {"level":"INFO","location":"get_parameter_value:32","message":"Intentando obtener el parámetro: /dev/agent-resources/chatbot","timestamp":"2025-05-13 17:48:06,381-0500","service":"service_undefined","name":"aje_libs.bd.helpers.pinecone_helper"}
# {"level":"INFO","location":"get_parameter_value:40","message":"Parámetro obtenido con éxito: /dev/agent-resources/chatbot","timestamp":"2025-05-13 17:48:08,750-0500","service":"service_undefined","name":"aje_libs.bd.helpers.pinecone_helper"}
# {"level":"INFO","location":"__init__:23","message":"Inicializando SecretsHelper para el secreto: dev/agent-resources/pinecone-api-key","timestamp":"2025-05-13 17:48:08,762-0500","service":"service_undefined","name":"aje_libs.bd.helpers.pinecone_helper"}
# {"level":"INFO","location":"get_secret_value:31","message":"Intentando obtener el secreto: dev/agent-resources/pinecone-api-key","timestamp":"2025-05-13 17:48:08,764-0500","service":"service_undefined","name":"aje_libs.bd.helpers.pinecone_helper"}
# {"level":"INFO","location":"get_secret_value:35","message":"Secreto obtenido con éxito: dev/agent-resources/pinecone-api-key","timestamp":"2025-05-13 17:48:13,134-0500","service":"service_undefined","name":"aje_libs.bd.helpers.pinecone_helper"}
# {"level":"INFO","location":"get_secret_value:43","message":"Retornando valor para la clave específica: PINECONE_INDEX_NAME","timestamp":"2025-05-13 17:48:13,135-0500","service":"service_undefined","name":"aje_libs.bd.helpers.pinecone_helper"}
# {"level":"INFO","location":"get_secret_value:31","message":"Intentando obtener el secreto: dev/agent-resources/pinecone-api-key","timestamp":"2025-05-13 17:48:13,136-0500","service":"service_undefined","name":"aje_libs.bd.helpers.pinecone_helper"}
# {"level":"INFO","location":"get_secret_value:35","message":"Secreto obtenido con éxito: dev/agent-resources/pinecone-api-key","timestamp":"2025-05-13 17:48:13,420-0500","service":"service_undefined","name":"aje_libs.bd.helpers.pinecone_helper"}
# {"level":"INFO","location":"get
357394099235535, 0.024120381101965904, 0.04399421066045761, -0.043455757200717926, -0.03150239959359169, 0.037054792046546936, -0.004010295495390892, 0.08128891885280609, -0.00012623747170437127, 0.05023522675037384, 0.01733786053955555, 0.0426480807363987, -0.04489773139357567, 0.028732312843203545, 0.011491979472339153, 0.005058503709733486, 0.015358351171016693, 0.05674608051776886, -0.04639708995819092, 0.0024524065665900707, -0.020119089633226395, -0.0329916886985302, -0.02141469717025757, -0.008678087033331394, -0.02619970217347145, -0.038272712379693985, 0.029487943276762962, -0.00526973232626915, 0.0202474445104599, -0.012368487194180489, 0.010922851972281933, -0.007004014682024717, 0.01996936835348606, -0.0032001782674342394, 0.023962873965501785, -0.0007002297206781805, -0.05393539369106293, -0.008887026458978653, -0.04492092877626419, 0.029820507392287254, 0.05179136246442795, -0.000952361267991364, 0.007947218604385853, -0.043515585362911224, 0.009839540347456932, -0.005077733658254147, 0.019160166382789612, 0.013153879903256893, 0.0009182502399198711, -0.020620035007596016, 0.02235942892730236, -0.03781149163842201, 0.001287519233301282, -0.042024776339530945, 0.0016751791117712855, -0.02333468198776245, -0.05600616708397865, 0.01008926797658205, 0.02819233573973179, -0.019119873642921448, 0.03492235392332077, -0.027806812897324562, -0.026276318356394768, 0.026887113228440285, 0.009118248708546162, 0.05839439854025841, 0.00394405797123909, 0.014307854697108269, - ...
# {"level":"INFO","location":"query:124","message":"Found 11","timestamp":"2025-05-13 17:49:51,439-0500","service":"service_undefined","name":"aje_libs.bd.helpers.pinecone_helper"}
# {"level":"INFO","location":"query:125","message":"Details: [{'id': 'de4f654f-6ef9-4d6e-92cb-6a1074929bde',\n 'metadata': {'drive_id': '1mpYIIgVUFIE1-hnM3hpD2jHfIFXRw4LY',\n              'file_hash': '377ba55d3bbdafc9880c1bdd274b47e25616aa40902af165521dd1ee7ef12d7b',\n              'pinecone_ids': [],\n              'resource_id': '-OOd7ppsIwUXCW9ynLiL',\n              'resource_title': '5. Plan Estratégico Colegio Modelo 2025 - '\n                                '2027 V5-1.pdf',\n              's3_path': 's3://sofia-509399624591-us-east-1-dev-agent-resources-resources-s3/SOFIA_FILE/PLANIFICACION/AV_Recursos/5__plan_estrategico_colegio_modelo_2025_-_2027_v5-1_pdf',\n              'text': 'de las TICs % del personal que percibe un clima '\n                      'organizacional cristiano favorable 95% 95% 95% 95% % '\n                      'estudiantes satisfechos con la enseñanza del docente % '\n                      'de docentes que alcanzan un desempeño adecuado Página '\n                      '41 Proyectos Estratégicos Cuando hagan cualquier '\n                      'trabajo, háganlo de todo corazón, como si estuvieran '\n                      'trabajando para el Señor y no para los seres humanos. '\n                      'Colosenses 3:23 Página 43 PROYECT OS AL 2027 P R O YE C '\n                      'T OS ES T R A T É G I C O S : P E R S P E C T I V A S '\n                      'DE RE SU LT AD O S 01 Proyecto Curricular de Liderazgo '\n                      '02 Proyecto Psicométrico para la evaluación de '\n                      'Liderazgo 03 Programas de Liderazgo de Servicio en el '\n                      'entorno 04 Portafolio de eventos institucionales, '\n                      'locales, regionales y nacionales de concursos Proyecto '\n                      'de Comunicación Efectiva de los logros 05 '\n                      'institucionales Proyecto de ampliación y/o '\n                      'diversificación de los servicios educativos 07 Proyecto '\n                      'de Franquicia Educativa Página 44 06 PROYECT OS AL 2027 '\n                      'P R O YE C T OS ES T R A T É G I C O S : P E R S P E C '\n                      'T I V A S DE C LI E N T E S Plan de evaluación '\n                      'progresía del logro del perfil de 08 egreso Proyecto de '\n                      'implementación del sistema de gestión 09 del perfil de '\n                      'egreso 10 Plan de encuesta de satisfacción del usuario '\n                      'Página 45 PROYECT OS AL 2027 P R O YE C T OS ES T R A T '\n                      'É G I C O S : P E R S P E C T I V A S DE P R OC E SO S '\n                      '11 Plan de Mejora Institucional 12 Proyecto de '\n                      'Implementación del Modelo Educativo 13 Plan Anual de '\n                      'Trabajo Programa de Implementación de Proyectos STEAM '\n                      'y/o 14 Experiencias de Aprendizaje Programa de Talleres '\n                      'para la Vida alineado a currículo 15 de emprendimiento '\n                      'Plan de evaluación progresiva de las competencias 16 '\n                      'Plan de implementación del Sistema de Gestión de la 17 '\n                      'Calidad Página 46 PROYECT OS AL 2027 P R O YE C T OS ES '\n                      'T R A T É G I C O S : P E R S P E C T I V A S DE A P R '\n                      'E N D I Z A J E Plan de actividades relacionadas al '\n                      'desarrollo 18 espiritual (PMDE) 19 Plan'},\n 'score': 0.319812298,\n 'values': []}, {'id': '15757722-72c5-426f-8091-abf9fb9ae3ba',\n 'metadata': {'drive_id': '1mpYIIgVUFIE1-hnM3hpD2jHfIFXRw4LY',\n              'file_hash': '377ba55d3bbdafc9880c1bdd274b47e25616aa40902af165521dd1ee7ef12d7b',\n              'pinecone_ids': [],\n              'resource_id': '-OOd7ppsIwUXCW9ynLiL',\n              'resource_title': '5. Plan Estratégico Colegio Modelo 2025 - '\n                                '2027 V5-1.pdf',\n              's3_path': 's3://sofi ...
# {"level":"INFO","location":"query:128","message":"Found 1 matches above threshold in Pinecone","timestamp":"2025-05-13 17:49:51,448-0500","service":"service_undefined","name":"aje_libs.bd.helpers.pinecone_helper"}

# %%
relevant_data
# Out:
# 'de las TICs % del personal que percibe un clima organizacional cristiano favorable 95% 95% 95% 95% % estudiantes satisfechos con la enseñanza del docente % de docentes que alcanzan un desempeño adecuado Página 41 Proyectos Estratégicos Cuando hagan cualquier trabajo, háganlo de todo corazón, como si estuvieran trabajando para el Señor y no para los seres humanos. Colosenses 3:23 Página 43 PROYECT OS AL 2027 P R O YE C T OS ES T R A T É G I C O S : P E R S P E C T I V A S DE RE SU LT AD O S 01 Proyecto Curricular de Liderazgo 02 Proyecto Psicométrico para la evaluación de Liderazgo 03 Programas de Liderazgo de Servicio en el entorno 04 Portafolio de eventos institucionales, locales, regionales y nacionales de concursos Proyecto de Comunicación Efectiva de los logros 05 institucionales Proyecto de ampliación y/o diversificación de los servicios educativos 07 Proyecto de Franquicia Educativa Página 44 06 PROYECT OS AL 2027 P R O YE C T OS ES T R A T É G I C O S : P E R S P E C T I V A S DE C LI E N T E S Plan de evaluación progresía del logro del perfil de 08 egreso Proyecto de implementación del sistema de gestión 09 del perfil de egreso 10 Plan de encuesta de satisfacción del usuario Página 45 PROYECT OS AL 2027 P R O YE C T OS ES T R A T É G I C O S : P E R S P E C T I V A S DE P R OC E SO S 11 Plan de Mejora Institucional 12 Proyecto de Implementación del Modelo Educativo 13 Plan Anual de Trabajo Programa de Implementación de Proyectos STEAM y/o 14 Experiencias de Aprendizaje Programa de Talleres para la Vida alineado a currículo 15 de emprendimiento Plan de evaluación progresiva de las competencias 16 Plan de implementación del Sistema de Gestión de la 17 Calidad Página 46 PROYECT OS AL 2027 P R O YE C T OS ES T R A T É G I C O S : P E R S P E C T I V A S DE A P R E N D I Z A J E Plan de actividades relacionadas al desarrollo 18 espiritual (PMDE) 19 Plan'
